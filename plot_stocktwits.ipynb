# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Stocktwits_Sentiment_30min.csv')

# %%
df.shape

# %%
df.head()
# Out:
#               DateTime  Tweets  Positive  Negative  Neutral  Positive %  \
# 0  2020-03-23 07:30:00      29         0        11       18    0.000000
# 1  2020-03-23 08:00:00     271        22        37      212    0.081181
# 2  2020-03-23 08:30:00     356        21        67      268    0.058989
# 3  2020-03-23 09:00:00     394        15        88      291    0.038071
# 4  2020-03-23 09:30:00     444        22        70      352    0.049550
#
#    Negative %  Neutral %  Sentiment Index
# 0    0.379310   0.620690        -0.379310
# 1    0.136531   0.782288        -0.055351
# 2    0.188202   0.752809        -0.129213
# 3    0.223350   0.738579        -0.185279
# 4    0.157658   0.792793        -0.108108

# %%
df['DateTime'] = pd.to_datetime(df['DateTime'])

# plot DateTime vs Tweets for the first 500 rows as line graph
df[:500].plot(x='DateTime', y='Sentiment Index', kind='line')
# Out:
# <AxesSubplot:xlabel='DateTime'>

# %%
# histogram of Sentiment Index with bins=20, ignoring outliers beyond 2 standard deviations
df['Sentiment Index'].plot(kind='hist', bins=100, range=[-0.3, 0.3])
# Out:
# <AxesSubplot:ylabel='Frequency'>
